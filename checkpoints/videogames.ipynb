# %%
# import libraries for data preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the csv file
df = pd.read_csv('Video-games.csv')

# %%
# info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# sum the null values in each column
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# replace the missing values with the mean of the year column
df['Year'].fillna(df['Year'].mean(), inplace=True)
df.Year
# Out:
# 0        2006.000000
# 1        1985.000000
# 2        2008.000000
# 3        2009.000000
# 4        1996.000000
# 5        1989.000000
# 6        2006.000000
# 7        2006.000000
# 8        2009.000000
# 9        1984.000000
# 10       2005.000000
# 11       2005.000000
# 12       1999.000000
# 13       2007.000000
# 14       2009.000000
# 15       2010.000000
# 16       2013.000000
# 17       2004.000000
# 18       1990.000000
# 19       2005.000000
# 20       2006.000000
# 21       1989.000000
# 22       1988.000000
# 23       2013.000000
# 24       2002.000000
# 25       2002.000000
# 26       2010.000000
# 27       2005.000000
# 28       2001.000000
# 29       2011.000000
# 30       1998.000000
# 31       2010.000000
# 32       2013.000000
# 33       2015.000000
# 34       2012.000000
# 35       2012.000000
# 36       2009.000000
# 37       2011.000000
# 38       2001.000000
# 39       2008.000000
# 40       2010.000000
# 41       2005.000000
# 42       2011.000000
# ...

# %%
# print the rows where the publisher column is null
df[df['Publisher'].isnull()]
# Out:
#         Rank                                               Name Platform
# 470      471                         wwe Smackdown vs. Raw 2006      PS2  \
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
# drop rows that has null values in the publisher column
df.dropna(subset=['Publisher'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo  \
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# an area chart showing the total sales of each year

# %%
# Create an area chart to show the trend of global sales over the years
df.groupby('Year')['Global_Sales'].sum().plot(kind='area', figsize=(15, 5))
plt.title('Global Sales over the years')
plt.ylabel('Global Sales')
plt.xlabel('Year')
plt.show()

# %%
ax2 = sns.lineplot(data=df, x='Year', y='Global_Sales', estimator=None, lw=2)

# Set title and labels
ax2.set_title('Area Chart using Seaborn')
ax2.set_xlabel('Year')
ax2.set_ylabel('Global Sales')

# Show the chart
plt.show()

# %%
fig, ax3 = plt.subplots()

# Fill the area under the curve
ax3.fill_between(df['Year'], df['Global_Sales'], color='blue', alpha=0.2)

# Draw the line
ax3.plot(df['Year'], df['Global_Sales'], color='blue', lw=2)

# Set title and labels
ax3.set_title('Area Chart using Matplotlib')
ax3.set_xlabel('Year')
ax3.set_ylabel('Global Sales')

# Show the chart
plt.show()

# %%
# Create a histogram to show the distribution of global sales using matplotlib
plt.hist(df['Global_Sales'])
# Out:
# (array([1.6458e+04, 5.9000e+01, 1.3000e+01, 7.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.0000e-02, 8.2830e+00, 1.6556e+01, 2.4829e+01, 3.3102e+01,
#         4.1375e+01, 4.9648e+01, 5.7921e+01, 6.6194e+01, 7.4467e+01,
#         8.2740e+01]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

# generate random exam scores for 30 students
scores = np.random.randint(50, 100, size=30)

# create histogram with 5 bins
plt.hist(scores, bins=5)

# add labels and title
plt.xlabel('Exam Scores')
plt.ylabel('Number of Students')
plt.title('Distribution of Exam Scores')

# show plot
plt.show()

# %%
# Create a scatter plot to show the relationship between North American sales and European sales

# %%
plt.scatter(df['NA_Sales'], df['EU_Sales'])
# => we can notice that the is an outlier in the data
# we can get it by using the following code

# %%
# we can get it by using the following code
df[(df['NA_Sales'] > 40) & (df['EU_Sales'] >20)]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02  \
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
# now we can drop it from the dataset
df.drop(2908, inplace=True)

# %%
# Create a scatter plot to show the relationship between Japanese sales and Other sales 
plt.scatter(df['JP_Sales'], df['Other_Sales'])
# we can notice that there are some outliers in the data 
# we can get them by using the following code
df[(df['JP_Sales'] > 10) & (df['Other_Sales'] > 5)]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
# Create a stacked area chart to show the distribution of sales by platform over the years using matplotlib
df.groupby(['Year', 'Platform'])['Global_Sales'].sum().unstack().plot(kind='area', stacked=True, figsize=(15, 5))
# Out:
# <Axes: xlabel='Year'>

# %%
#  => i did not understand it the groupby function

# %%
# Create a bar chart to show the top 10 publishers by global sales using matplotlib
df.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(15, 5))
# Out:
# <Axes: xlabel='Publisher'>

# %%
# understanding how the groupby works
# df.groupby('Genre').sum()
df.groupby('Genre').head()
# => why its not being sorted or grouped by the genre column
# Out:
#      Rank                                          Name Platform    Year
# 0       1                                    Wii Sports      Wii  2006.0  \
# 1       2                             Super Mario Bros.      NES  1985.0
# 2       3                                Mario Kart Wii      Wii  2008.0
# 3       4                             Wii Sports Resort      Wii  2009.0
# 4       5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5       6                                        Tetris       GB  1989.0
# 6       7                         New Super Mario Bros.       DS  2006.0
# 7       8                                      Wii Play      Wii  2006.0
# 8       9                     New Super Mario Bros. Wii      Wii  2009.0
# 9      10                                     Duck Hunt      NES  1984.0
# 10     11                                    Nintendogs       DS  2005.0
# 11     12                                 Mario Kart DS       DS  2005.0
# ...
